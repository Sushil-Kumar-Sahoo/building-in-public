# %% [markdown]
# ## Machine Learning Resources :

# %% [markdown]
# <iframe src="https://drive.google.com/file/d/1slE1JegYj6WfY5EF8b4HxAL6GmEpeuvT/preview" width="100%" height="700" allow="autoplay"></iframe>

# %% [markdown]
# https://drive.google.com/file/d/1slE1JegYj6WfY5EF8b4HxAL6GmEpeuvT/view?usp=sharing
# <!-- - [O'Reilly : Introduction to Machine Learning with Python](https://drive.google.com/file/d/1slE1JegYj6WfY5EF8b4HxAL6GmEpeuvT/view) -->
