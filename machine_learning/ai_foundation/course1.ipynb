# %%
import numpy as np
import random

# %%
def test_probabilities(words, probs):
    assert np.all(np.array(probs) >= 0), "All probabilities must be non-negative"
    assert np.isclose(np.sum(probs), 1.0), "Probabilities must sum to 1.0"
    print("Correct !")

# %%
candidates_words = ['star','beef','bottle']
mental_model = [0.99, 0.001, 0.009]
test_probabilities(candidates_words,mental_model)
# Out:
# Correct !

# %%
chosen_word = random.choices(candidates_words,weights=mental_model,k=1) 
print(f"Twinkle twinkle little {chosen_word[0]}.")
# Out:
# Twinkle twinkle little star.

# %%
candidate_words = ['desert', 'with', 'ocean', 'the', 'after', 'sun', 'set', 'over']
probabilities = [0.1, 0.61, 0.001, 0.2, 0.05, 0.0081, 0.0009, 0.03]
test_probabilities(candidates_words,probabilities)
# Out:
# Correct !

# %%
(700000*5*x) + (300000*x) = 1
3500000*x +
# Out:
#   Cell In[3], line 1
#     (700000*5*x) + (300000*x) = 1
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# Out:
# 0.3

# %%
# Out:
# 3800000

# %%
x= 2.632
